# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Mortality Ratios Data

# %%
mortality_ratios = pd.read_csv('../data/raw_data/abortion_pregnancy_death_ratios_cdc.csv')
mortality_ratios.head()
# Out:
#    Year   Mortality Ratio  Counts
# 0   1987              7.2     275
# 1   1988              9.4     369
# 2   1989              9.8     394
# 3   1990             10.0     415
# 4   1991             10.3     424

# %%
mortality_ratios_clean = mortality_ratios.drop(columns= ['Counts'])
mortality_ratios_clean
mortality_ratios_clean.to_csv('../data/clean_data/clean_mortality_ratios.csv')

# %% [markdown]
# # Maternal Mortality By Policy Index

# %%
policy_mat_mort = pd.read_csv('../data/raw_data/TABLE 1— Total Maternal Mortality (TMM), Maternal Mortality (MM), and Late Maternal Mortality (LMM; 2015–2018) and State-Level Covariates (2015) by Tertile of State Abortion Policy Composite Index_ United States - Sheet1.csv')
policy_mat_mort.head()
# Out:
#                                             Variable  \
# 0                        TMM per 100,000 live births
# 1                         MM per 100,000 live births
# 2                        LMM per 100,000 live births
# 3              Abortion policy composite index, 2015
# 4  Poverty (% of state population with income bel...
#
#   All States (n = 51), Mean ± SD or No. (%)  \
# 0                              24.62 ± 8.89
# 1                              17.78 ± 7.13
# 2                               7.02 ± 2.86
# 3                               3.75 ± 2.46
# 4                              14.85 ± 3.17
#
#   Low (n = 15), Mean ± SD or No. (%) Moderate (n = 17), Mean ± SD or No. (%)  \
# 0                       20.79 ± 5.25                            22.04 ± 7.60
# 1                       14.83 ± 3.89                            15.81 ± 6.10
# 2                        6.32 ± 2.34                             6.23 ± 2.73
# ...

# %% [markdown]
# # Individual Policy & Maternal Mortality

# %%
policy = pd.read_csv('../data/raw_data/Associations Between Total Maternal Mortality (TMM), Maternal Mortality (MM), and Late Maternal Mortality (LMM) and Abortion Policies_ United States, 2015–2018 - Sheet1.csv')
policy.head()
# Out:
#                               Variable  TMM, ARR (95% CI)   MM, ARR (95% CI)  \
# 0      Abortion policy composite index  1.07 (1.02, 1.12)  1.02 (0.94, 1.10)
# 1  State abortion policies (yes vs no)                NaN                NaN
# 2                  Mandated counseling  1.13 (0.90, 1.43)  0.98 (0.78, 1.23)
# 3                       Waiting period  1.16 (0.97, 1.38)  1.05 (0.77, 1.43)
# 4               Ultrasound requirement  1.20 (0.96, 1.49)  1.07 (0.75, 1.52)
#
#    LMM, ARR (95% CI)
# 0  1.01 (0.95, 1.08)
# 1                NaN
# 2  1.00 (0.77, 1.31)
# 3  0.99 (0.72, 1.36)
# 4  0.94 (0.70, 1.26)

# %% [markdown]
# # Abortions by Weeks of Gestation

# %%
abortion_time = pd.read_csv('../data/raw_data/Number of reported abortions, by known weeks of gestation_ and reporting area of occurrence — selected reporting areas,† United States, 2019 (https___www.cdc.gov_mmwr_volumes_70_ss_ss7009a1.htm#T10_down) - Sheet1.csv')
abortion_time.head()
# Out:
#   State/Area Weeks of gestation    Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 0        NaN                 ≤6           7–9         10–13      14–15
# 1        NaN           No. (%)§       No. (%)       No. (%)    No. (%)
# 2  Alabama**       1,280 (21.3)  2,807 (46.8)  1,257 (20.9)  317 (5.3)
# 3     Alaska         292 (23.0)    639 (50.4)    271 (21.4)   64 (5.0)
# 4    Arizona       3,863 (29.5)  5,985 (45.7)  2,079 (15.9)  496 (3.8)
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0      16–17      18–20        ≥21
# 1    No. (%)    No. (%)    No. (%)
# 2  163 (2.7)  133 (2.2)   46 (0.8)
# 3        —††        —††      0 (—)
# 4  261 (2.0)  245 (1.9)  168 (1.3)
#
#   Total abortions reported by known gestational age
# 0                                               NaN
# 1                No. (% of all reported abortions)¶
# 2                                      6,003 (99.9)
# 3                                      1,269 (99.9)
# 4                                    13,097 (100.0)
